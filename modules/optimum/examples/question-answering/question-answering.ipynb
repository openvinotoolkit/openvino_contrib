# %% [markdown]
# ## OpenVINO optimizations for Question answering (QA) task

# %% [markdown]
# ## Import the packages needed for successful execution

# %%
from transformers import pipeline
from datasets import load_dataset, load_metric
from optimum.intel.openvino import OVAutoModelForQuestionAnswering

from tqdm import tqdm

from pathlib import Path

# Required for OpenVINO conversion
output_dir = Path("ov_optimized_model")
base_model_name = "ov_model"
output_dir.mkdir(exist_ok=True)

# Paths where OpenVINO IR models will be stored
fp32_model_path = Path(output_dir / base_model_name).with_suffix(".xml")

seq_len = 256

# %% [markdown]
# ### Instructions on conversion to OpenVINO
# We will use the OV optimum module to convert the PyTorch Question answering pre-trained model to an OpenVINO model object. <br>
# We will then use Huggingface datasets and metric to evaluate the converted model.

# %%
model = 'bert-large-uncased-whole-word-masking-finetuned-squad'
ov_model = OVAutoModelForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad', from_pt=True)
qa_pipeline = pipeline("question-answering", model=ov_model, tokenizer='bert-large-uncased-whole-word-masking-finetuned-squad')
dataset = load_dataset("squad", split="validation")
metric = load_metric('squad')

for idx, batch in enumerate(tqdm(dataset, desc="Looping over validation data")):
    input_context = batch['context']
    input_questions = batch['question']
    references = batch['answers']
    preds = qa_pipeline(question=batch['question'], context=batch['context'])
    
    predictions = [{'prediction_text': preds['answer'], 'id': batch['id']}]
    references = [{'answers': batch['answers'], 'id': batch['id']}]
    metric.add_batch(predictions=predictions, references=references)

score = metric.compute()
print(f'Score for squad dataset: {score}')
# Out:
# [W shape_type_inference.cpp:419] Warning: Constant folding in symbolic shape inference fails: index_select(): Index is supposed to be a vector
# Exception raised from index_select_out_cpu_ at /pytorch/aten/src/ATen/native/TensorAdvancedIndexing.cpp:758 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x42 (0x7fd9a4c68a22 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libc10.so)
# frame #1: at::native::index_select_out_cpu_(at::Tensor const&, long, at::Tensor const&, at::Tensor&) + 0x2a9 (0x7fd9e88727d9 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #2: at::native::index_select_cpu_(at::Tensor const&, long, at::Tensor const&) + 0x60 (0x7fd9e8875230 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #3: <unknown function> + 0x1a00352 (0x7fd9e8fea352 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #4: at::redispatch::index_select(c10::DispatchKeySet, at::Tensor const&, long, at::Tensor const&) + 0xb4 (0x7fd9e8e6c714 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #5: <unknown function> + 0x3010461 (0x7fd9ea5fa461 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #6: <unknown function> + 0x30108b5 (0x7fd9ea5fa8b5 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #7: at::index_select(at::Tensor const&, long, at::Tensor const&) + 0x14e (0x7fd9e8c8b50e in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #8: torch::jit::onnx_constant_fold::runTorchBackendForOnnx(torch::jit::Node const*, std::vector<at::Tensor, std::allocator<at::Tensor> >&, int) + 0x1b50 (0x7fd9fb848f00 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #9: <unknown function> + 0xaecf7e (0x7fd9fb885f7e in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #10: torch::jit::ONNXShapeTypeInference(torch::jit::Node*, std::map<std::string, c10::IValue, std::less<std::string>, std::allocator<std::pair<std::string const, c10::IValue> > > const&, int) + 0x906 (0x7fd9fb88ad36 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #11: <unknown function> + 0xaf49e4 (0x7fd9fb88d9e4 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #12: <unknown function> + 0xa70c00 (0x7fd9fb809c00 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #13: <unknown function> + 0x5011ee (0x7fd9fb29a1ee in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #14: <unknown function> + 0x13c00e (0x55c6bc37500e in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #15: _PyObject_MakeTpCall + 0x3bf (0x55c6bc36a13f in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #16: _PyEval_EvalFrameDefault + 0x5434 (0x55c6bc414dd4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #17: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #18: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #19: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #20: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #21: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #22: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #23: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #24: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #25: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #26: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #27: _PyFunction_Vectorcall + 0x534 (0x55c6bc406b64 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #28: _PyEval_EvalFrameDefault + 0x4f83 (0x55c6bc414923 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #29: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #30: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #31: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #32: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #33: _PyFunction_Vectorcall + 0x534 (0x55c6bc406b64 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #34: _PyEval_EvalFrameDefault + 0x71b (0x55c6bc4100bb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #35: _PyEval_EvalCodeWithName + 0xd5f (0x55c6bc4060ff in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #36: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #37: <unknown function> + 0x166b2e (0x55c6bc39fb2e in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #38: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #39: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #40: <unknown function> + 0x1f98df (0x55c6bc4328df in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #41: <unknown function> + 0x13b23d (0x55c6bc37423d in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #42: _PyEval_EvalFrameDefault + 0x71b (0x55c6bc4100bb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #43: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #44: _PyEval_EvalFrameDefault + 0x1b5b (0x55c6bc4114fb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #45: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #46: _PyEval_EvalFrameDefault + 0x1b5b (0x55c6bc4114fb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #47: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #48: <unknown function> + 0x17cd15 (0x55c6bc3b5d15 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #49: _PyEval_EvalFrameDefault + 0x4c0 (0x55c6bc40fe60 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #50: _PyFunction_Vectorcall + 0x1b7 (0x55c6bc4067e7 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #51: _PyEval_EvalFrameDefault + 0x71b (0x55c6bc4100bb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #52: _PyFunction_Vectorcall + 0x1b7 (0x55c6bc4067e7 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #53: _PyEval_EvalFrameDefault + 0x4c0 (0x55c6bc40fe60 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #54: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #55: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #56: <unknown function> + 0x166bf8 (0x55c6bc39fbf8 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #57: PyObject_Call + 0x319 (0x55c6bc3704a9 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #58: _PyEval_EvalFrameDefault + 0x1f07 (0x55c6bc4118a7 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #59: _PyEval_EvalCodeWithName + 0x888 (0x55c6bc405c28 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #60: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #61: <unknown function> + 0x166b2e (0x55c6bc39fb2e in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #62: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #63: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
#  (function ComputeConstantFolding)
# [W shape_type_inference.cpp:419] Warning: Constant folding in symbolic shape inference fails: index_select(): Index is supposed to be a vector
# Exception raised from index_select_out_cpu_ at /pytorch/aten/src/ATen/native/TensorAdvancedIndexing.cpp:758 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x42 (0x7fd9a4c68a22 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libc10.so)
# frame #1: at::native::index_select_out_cpu_(at::Tensor const&, long, at::Tensor const&, at::Tensor&) + 0x2a9 (0x7fd9e88727d9 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #2: at::native::index_select_cpu_(at::Tensor const&, long, at::Tensor const&) + 0x60 (0x7fd9e8875230 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #3: <unknown function> + 0x1a00352 (0x7fd9e8fea352 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #4: at::redispatch::index_select(c10::DispatchKeySet, at::Tensor const&, long, at::Tensor const&) + 0xb4 (0x7fd9e8e6c714 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #5: <unknown function> + 0x3010461 (0x7fd9ea5fa461 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #6: <unknown function> + 0x30108b5 (0x7fd9ea5fa8b5 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #7: at::index_select(at::Tensor const&, long, at::Tensor const&) + 0x14e (0x7fd9e8c8b50e in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_cpu.so)
# frame #8: torch::jit::onnx_constant_fold::runTorchBackendForOnnx(torch::jit::Node const*, std::vector<at::Tensor, std::allocator<at::Tensor> >&, int) + 0x1b50 (0x7fd9fb848f00 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #9: <unknown function> + 0xaecf7e (0x7fd9fb885f7e in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #10: torch::jit::ONNXShapeTypeInference(torch::jit::Node*, std::map<std::string, c10::IValue, std::less<std::string>, std::allocator<std::pair<std::string const, c10::IValue> > > const&, int) + 0x906 (0x7fd9fb88ad36 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #11: <unknown function> + 0xaf49e4 (0x7fd9fb88d9e4 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #12: <unknown function> + 0xa70c00 (0x7fd9fb809c00 in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #13: <unknown function> + 0x5011ee (0x7fd9fb29a1ee in /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #14: <unknown function> + 0x13c00e (0x55c6bc37500e in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #15: _PyObject_MakeTpCall + 0x3bf (0x55c6bc36a13f in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #16: _PyEval_EvalFrameDefault + 0x5434 (0x55c6bc414dd4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #17: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #18: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #19: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #20: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #21: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #22: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #23: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #24: _PyFunction_Vectorcall + 0x534 (0x55c6bc406b64 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #25: _PyEval_EvalFrameDefault + 0x4f83 (0x55c6bc414923 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #26: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #27: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #28: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #29: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #30: _PyFunction_Vectorcall + 0x534 (0x55c6bc406b64 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #31: _PyEval_EvalFrameDefault + 0x71b (0x55c6bc4100bb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #32: _PyEval_EvalCodeWithName + 0xd5f (0x55c6bc4060ff in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #33: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #34: <unknown function> + 0x166b2e (0x55c6bc39fb2e in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #35: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #36: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #37: <unknown function> + 0x1f98df (0x55c6bc4328df in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #38: <unknown function> + 0x13b23d (0x55c6bc37423d in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #39: _PyEval_EvalFrameDefault + 0x71b (0x55c6bc4100bb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #40: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #41: _PyEval_EvalFrameDefault + 0x1b5b (0x55c6bc4114fb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #42: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #43: _PyEval_EvalFrameDefault + 0x1b5b (0x55c6bc4114fb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #44: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #45: <unknown function> + 0x17cd15 (0x55c6bc3b5d15 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #46: _PyEval_EvalFrameDefault + 0x4c0 (0x55c6bc40fe60 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #47: _PyFunction_Vectorcall + 0x1b7 (0x55c6bc4067e7 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #48: _PyEval_EvalFrameDefault + 0x71b (0x55c6bc4100bb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #49: _PyFunction_Vectorcall + 0x1b7 (0x55c6bc4067e7 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #50: _PyEval_EvalFrameDefault + 0x4c0 (0x55c6bc40fe60 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #51: _PyEval_EvalCodeWithName + 0x260 (0x55c6bc405600 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #52: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #53: <unknown function> + 0x166bf8 (0x55c6bc39fbf8 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #54: PyObject_Call + 0x319 (0x55c6bc3704a9 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #55: _PyEval_EvalFrameDefault + 0x1f07 (0x55c6bc4118a7 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #56: _PyEval_EvalCodeWithName + 0x888 (0x55c6bc405c28 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #57: _PyFunction_Vectorcall + 0x594 (0x55c6bc406bc4 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #58: <unknown function> + 0x166b2e (0x55c6bc39fb2e in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #59: _PyEval_EvalFrameDefault + 0x1510 (0x55c6bc410eb0 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #60: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #61: _PyEval_EvalFrameDefault + 0x1b5b (0x55c6bc4114fb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #62: <unknown function> + 0x1955c2 (0x55c6bc3ce5c2 in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
# frame #63: _PyEval_EvalFrameDefault + 0x1b5b (0x55c6bc4114fb in /home/dkarkada/miniconda3/envs/optimumtests/bin/python)
#  (function ComputeConstantFolding)
# The model 'OVPreTrainedModel' is not supported for question-answering. Supported models are ['YosoForQuestionAnswering', 'NystromformerForQuestionAnswering', 'QDQBertForQuestionAnswering', 'FNetForQuestionAnswering', 'GPTJForQuestionAnswering', 'LayoutLMv2ForQuestionAnswering', 'RemBertForQuestionAnswering', 'CanineForQuestionAnswering', 'RoFormerForQuestionAnswering', 'BigBirdPegasusForQuestionAnswering', 'BigBirdForQuestionAnswering', 'ConvBertForQuestionAnswering', 'LEDForQuestionAnswering', 'DistilBertForQuestionAnswering', 'AlbertForQuestionAnswering', 'CamembertForQuestionAnswering', 'BartForQuestionAnswering', 'MBartForQuestionAnswering', 'LongformerForQuestionAnswering', 'XLMRobertaXLForQuestionAnswering', 'XLMRobertaForQuestionAnswering', 'RobertaForQuestionAnswering', 'SqueezeBertForQuestionAnswering', 'BertForQuestionAnswering', 'XLNetForQuestionAnsweringSimple', 'FlaubertForQuestionAnsweringSimple', 'MegatronBertForQuestionAnswering', 'MobileBertForQuestionAnswering', 'XLMForQuestionAnsweringSimple', 'ElectraForQuestionAnswering', 'ReformerForQuestionAnswering', 'FunnelForQuestionAnswering', 'LxmertForQuestionAnswering', 'MPNetForQuestionAnswering', 'DebertaForQuestionAnswering', 'DebertaV2ForQuestionAnswering', 'IBertForQuestionAnswering', 'SplinterForQuestionAnswering', 'Data2VecTextForQuestionAnswering'].
# Reusing dataset squad (/home/dkarkada/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
# Looping over validation data:   2%|▏         | 250/10570 [00:32<24:31,  7.01it/s] /home/dkarkada/miniconda3/envs/optimumtests/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Looping over validation data: 100%|██████████| 10570/10570 [20:11<00:00,  8.72it/s]
# Score for squad dataset: {'exact_match': 86.5752128666036, 'f1': 92.93190288050819}

# %%
ov_model.save_pretrained(output_dir)

# %% [markdown]
# ### Benchmark the converted model using the benchmark app

# %%
print('Benchmark OpenVINO model using the benchmark app')
! benchmark_app -m "$fp32_model_path" -d CPU -api async -t 10 -data_shape [1,"$seq_len"]
# Out:
# Benchmark OpenVINO model using the benchmark app
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [Step 1/11] Parsing and validating input arguments
# [ WARNING ]  -nstreams default value is determined automatically for a device. Although the automatic selection usually provides a reasonable performance, but it still may be non-optimal for some cases, for more information look at README.
# [Step 2/11] Loading OpenVINO
# [ WARNING ] PerformanceMode was not explicitly specified in command line. Device CPU performance hint will be set to THROUGHPUT.
# [ INFO ] OpenVINO:
#          API version............. 2022.1.0-7019-cdb9bec7210-releases/2022/1
# [ INFO ] Device info
#          CPU
#          openvino_intel_cpu_plugin version 2022.1
#          Build................... 2022.1.0-7019-cdb9bec7210-releases/2022/1
#
# [Step 3/11] Setting device configuration
# [ WARNING ] -nstreams default value is determined automatically for CPU device. Although the automatic selection usually provides a reasonable performance, but it still may be non-optimal for some cases, for more information look at README.
# [Step 4/11] Reading network files
# [ INFO ] Read model took 1014.44 ms
# [Step 5/11] Resizing network to match image sizes and given batch
# [ INFO ] Network batch size: 1
# [Step 6/11] Configuring input of the model
# [ INFO ] Model input 'input_ids' precision i32, dimensions ([...]): ? ?
# [ INFO ] Model input 'attention_mask' precision i32, dimensions ([...]): ? ?
# [ INFO ] Model output 'output_s' precision f32, dimensions ([...]): ? ?
# [ INFO ] Model output 'output_e' precision f32, dimensions ([...]): ? ?
# [Step 7/11] Loading the model to the device
# [ INFO ] Compile model took 7011.14 ms
# [Step 8/11] Querying optimal runtime parameters
# [ INFO ] DEVICE: CPU
# [ INFO ]   AVAILABLE_DEVICES  , ['']
# [ INFO ]   RANGE_FOR_ASYNC_INFER_REQUESTS  , (1, 1, 1)
# [ INFO ]   RANGE_FOR_STREAMS  , (1, 96)
# [ INFO ]   FULL_DEVICE_NAME  , Intel(R) Xeon(R) Gold 6252N CPU @ 2.30GHz
# [ INFO ]   OPTIMIZATION_CAPABILITIES  , ['WINOGRAD', 'FP32', 'FP16', 'INT8', 'BIN', 'EXPORT_IMPORT']
# [ INFO ]   CACHE_DIR  ,
# [ INFO ]   NUM_STREAMS  , 12
# [ INFO ]   INFERENCE_NUM_THREADS  , 0
# [ INFO ]   PERF_COUNT  , False
# [ INFO ]   PERFORMANCE_HINT_NUM_REQUESTS  , 0
# [Step 9/11] Creating infer requests and preparing input data
# [ INFO ] Create 12 infer requests took 4.69 ms
# [ WARNING ] No input files were given for input 'input_ids'!. This input will be filled with random values!
# [ WARNING ] No input files were given for input 'attention_mask'!. This input will be filled with random values!
# [ INFO ] Fill input 'input_ids' with random values
# [ INFO ] Fill input 'attention_mask' with random values
# [Step 10/11] Measuring performance (Start inference asynchronously, 12 inference requests using 12 streams for CPU, inference only: False, limits: 10000 ms duration)
# [ INFO ] Benchmarking in full mode (inputs filling are included in measurement loop).
# [ INFO ] First inference took 540.16 ms
# [Step 11/11] Dumping statistics report
# Count:          207 iterations
# Duration:       10491.60 ms
# Latency:
#     AVG:        597.11 ms
#     MIN:        444.21 ms
#     MAX:        1468.31 ms
# Throughput: 19.73 FPS
